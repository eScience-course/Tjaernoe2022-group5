# %%
from miditime.miditime import MIDITime
import numpy as np
import pandas as pd

# %%
def to_midi(infile,nm):
    mymidi = MIDITime(160, nm+'.mid')
    tt = pd.read_csv(infile,skiprows=1,header=None,index_col=0)
    tt = np.array(tt)
    tt = tt.tolist()
    print(tt)
    # Add a track with those notes                                                                                                                                                                              
    mymidi.add_track(tt)
    # Output the .mid file                                                                                                                                                                                      
    mymidi.save_midi()

# %%
to_midi('arcmus245','arcmus245')
to_midi('arcmus585','arcmus585')
# Out:
# [[1, 37, 127, 1], [2, 35, 127, 1], [3, 33, 127, 1], [4, 22, 127, 1], [5, 35, 127, 1], [6, 39, 127, 1], [7, 51, 127, 1], [8, 32, 127, 1], [9, 45, 127, 1], [10, 40, 127, 1], [11, 50, 127, 1], [12, 42, 127, 1], [13, 38, 127, 1], [14, 48, 127, 1], [15, 46, 127, 1], [16, 41, 127, 1], [17, 48, 127, 1], [18, 51, 127, 1], [19, 46, 127, 1], [20, 48, 127, 1], [21, 39, 127, 1], [22, 56, 127, 1], [23, 46, 127, 1], [24, 43, 127, 1], [25, 56, 127, 1], [26, 41, 127, 1], [27, 32, 127, 1], [28, 41, 127, 2], [30, 49, 127, 1], [31, 37, 127, 1], [32, 41, 127, 1], [33, 38, 127, 1], [34, 36, 127, 1], [35, 51, 127, 1], [36, 56, 127, 1], [37, 49, 127, 1], [38, 66, 127, 1], [39, 52, 127, 1], [40, 61, 127, 1], [41, 54, 127, 1], [42, 60, 127, 1], [43, 43, 127, 1], [44, 35, 127, 1], [45, 44, 127, 1], [46, 52, 127, 1], [47, 58, 127, 1], [48, 54, 127, 1], [49, 63, 127, 1], [50, 59, 127, 1], [51, 57, 127, 1], [52, 48, 127, 1], [53, 54, 127, 1], [54, 49, 127, 1], [55, 44, 127, 1], [56, 59, 127, 1], [57, 43, 127, 1]
# ...
