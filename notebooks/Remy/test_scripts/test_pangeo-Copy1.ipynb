# %%
import xarray as xr
xr.set_options(display_style='html')
import intake
import cftime
import matplotlib.pyplot as plt
import numpy as np
from netCDF4 import Dataset

# %%
cat_url = "https://storage.googleapis.com/cmip6/pangeo-cmip6.json"
col = intake.open_esm_datastore(cat_url)
col
# Out:
# <p><strong>pangeo-cmip6 catalog with 7674 dataset(s) from 514818 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>activity_id</th>
#       <td>18</td>
#     </tr>
#     <tr>
#       <th>institution_id</th>
#       <td>36</td>
#     </tr>
#     <tr>
#       <th>source_id</th>
#       <td>88</td>
#     </tr>
#     <tr>
#       <th>experiment_id</th>
#       <td>170</td>
#     </tr>
#     <tr>
#       <th>member_id</th>
#       <td>657</td>
#     </tr>
#     <tr>
#       <th>table_id</th>
#       <td>37</td>
#     </tr>
#     <tr>
#       <th>variable_id</th>
#       <td>700</td>
#     </tr>
#     <tr>
#       <th>grid_label</th>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>zstore</th>
#       <td>514818</td>
#     </tr>
#     <tr>
#       <th>dcpp_init_year</th>
#       <td>60</td>
#     </tr>
#     <tr>
#       <th>version</th>
#       <td>736</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
cat = col.search(source_id=['NorESM2-LM'], variable_id=['clt'], member_id=['r1i1p1f1'])
cat.df
# Out:
#     activity_id institution_id   source_id    experiment_id member_id  \
# 0          CMIP            NCC  NorESM2-LM          1pctCO2  r1i1p1f1
# 1          CMIP            NCC  NorESM2-LM          1pctCO2  r1i1p1f1
# 2          CMIP            NCC  NorESM2-LM       historical  r1i1p1f1
# 3          CMIP            NCC  NorESM2-LM       historical  r1i1p1f1
# 4         PAMIP            NCC  NorESM2-LM  pdSST-futArcSIC  r1i1p1f1
# 5         PAMIP            NCC  NorESM2-LM      pdSST-pdSIC  r1i1p1f1
# 6         PAMIP            NCC  NorESM2-LM   pdSST-piArcSIC  r1i1p1f1
# 7          CMIP            NCC  NorESM2-LM    esm-piControl  r1i1p1f1
# 8   ScenarioMIP            NCC  NorESM2-LM           ssp245  r1i1p1f1
# 9   ScenarioMIP            NCC  NorESM2-LM           ssp245  r1i1p1f1
# 10  ScenarioMIP            NCC  NorESM2-LM           ssp585  r1i1p1f1
# 11  ScenarioMIP            NCC  NorESM2-LM           ssp585  r1i1p1f1
# 12  ScenarioMIP            NCC  NorESM2-LM           ssp126  r1i1p1f1
# 13  ScenarioMIP            NCC  NorESM2-LM           ssp370  r1i1p1f1
# 14  ScenarioMIP            NCC  NorESM2-LM           ssp370  r1i1p1f1
# 15        C4MIP            NCC  NorESM2-LM       esm-ssp585  r1i1p1f1
# 16         CMIP            NCC  NorESM2-LM         esm-hist  r1i1p1f1
# 17         CMIP            NCC  NorESM2-LM        piControl  r1i1p1f1
# 18         CMIP            NCC  NorESM2-LM        piControl  r1i1p1f1
# 19         CMIP            NCC  NorESM2-LM     abrupt-4xCO2  r1i1p1f1
# 20         CMIP            NCC  NorESM2-LM     abrupt-4xCO2  r1i1p1f1
#
#    table_id variable_id grid_label  \
# 0      Amon         clt         gn
# 1       day         clt         gn
# 2       day         clt         gn
# 3      Amon         clt         gn
# 4      Amon         clt         gn
# 5      Amon         clt         gn
# 6      Amon         clt         gn
# 7      Amon         clt         gn
# 8      Amon         clt         gn
# 9       day         clt         gn
# 10     Amon         clt         gn
# 11      day         clt         gn
# 12     Amon         clt         gn
# 13      day         clt         gn
# 14     Amon         clt         gn
# 15     Amon         clt         gn
# 16     Amon         clt         gn
# 17      day         clt         gn
# 18     Amon         clt         gn
# 19      day         clt         gn
# 20     Amon         clt         gn
#
#                                                zstore  dcpp_init_year  \
# 0   gs://cmip6/CMIP6/CMIP/NCC/NorESM2-LM/1pctCO2/r...             NaN
# 1   gs://cmip6/CMIP6/CMIP/NCC/NorESM2-LM/1pctCO2/r...             NaN
# 2   gs://cmip6/CMIP6/CMIP/NCC/NorESM2-LM/historica...             NaN
# 3   gs://cmip6/CMIP6/CMIP/NCC/NorESM2-LM/historica...             NaN
# 4   gs://cmip6/CMIP6/PAMIP/NCC/NorESM2-LM/pdSST-fu...             NaN
# 5   gs://cmip6/CMIP6/PAMIP/NCC/NorESM2-LM/pdSST-pd...             NaN
# 6   gs://cmip6/CMIP6/PAMIP/NCC/NorESM2-LM/pdSST-pi...             NaN
# 7   gs://cmip6/CMIP6/CMIP/NCC/NorESM2-LM/esm-piCon...             NaN
# 8   gs://cmip6/CMIP6/ScenarioMIP/NCC/NorESM2-LM/ss...             NaN
# 9   gs://cmip6/CMIP6/ScenarioMIP/NCC/NorESM2-LM/ss...             NaN
# 10  gs://cmip6/CMIP6/ScenarioMIP/NCC/NorESM2-LM/ss...             NaN
# 11  gs://cmip6/CMIP6/ScenarioMIP/NCC/NorESM2-LM/ss...             NaN
# 12  gs://cmip6/CMIP6/ScenarioMIP/NCC/NorESM2-LM/ss...             NaN
# 13  gs://cmip6/CMIP6/ScenarioMIP/NCC/NorESM2-LM/ss...             NaN
# 14  gs://cmip6/CMIP6/ScenarioMIP/NCC/NorESM2-LM/ss...             NaN
# 15  gs://cmip6/CMIP6/C4MIP/NCC/NorESM2-LM/esm-ssp5...             NaN
# 16  gs://cmip6/CMIP6/CMIP/NCC/NorESM2-LM/esm-hist/...             NaN
# 17  gs://cmip6/CMIP6/CMIP/NCC/NorESM2-LM/piControl...             NaN
# 18  gs://cmip6/CMIP6/CMIP/NCC/NorESM2-LM/piControl...             NaN
# 19  gs://cmip6/CMIP6/CMIP/NCC/NorESM2-LM/abrupt-4x...             NaN
# 20  gs://cmip6/CMIP6/CMIP/NCC/NorESM2-LM/abrupt-4x...             NaN
#
#      version
# 0   20190815
# 1   20190815
# 2   20190815
# 3   20190815
# 4   20190920
# 5   20190920
# 6   20190920
# 7   20190920
# 8   20191108
# 9   20191108
# 10  20191108
# 11  20191108
# 12  20191108
# 13  20191108
# 14  20191108
# 15  20200218
# 16  20200218
# 17  20210118
# 18  20210118
# 19  20210118
# 20  20210118

# %%
dset_dict = cat.to_dataset_dict(zarr_kwargs={'use_cftime':True})
# Out:
# /srv/conda/envs/notebook/lib/python3.9/site-packages/intake_esm/core.py:882: UserWarning: There are no datasets to load! Returning an empty dictionary.
#   warn('There are no datasets to load! Returning an empty dictionary.')

# %% [markdown]
# `intake-esm` is build on top of [pandas](https://pandas.pydata.org/pandas-docs/stable). It is possible to view the `pandas.DataFrame` as follows.

# %%
dataset_list = list(dset_dict.keys())
dataset_list
# Out:
# []

# %%
dset = dset_dict[dataset_list[0]]
dset = dset.sel(member_id='r1i1p1f1',time=slice("2000-01-01", "2014-12-31"))
dset
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 dset = dset_dict[dataset_list[0]]
#       2 dset = dset.sel(member_id='r1i1p1f1',time=slice("2000-01-01", "2014-12-31"))
#       3 dset
#
# IndexError: list index out of range
