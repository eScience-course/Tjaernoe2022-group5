# %%
import xarray as xr
xr.set_options(display_style='html')
import intake
import cftime
import matplotlib.pyplot as plt
import numpy as np
from netCDF4 import Dataset

# %%
cat_url = "https://storage.googleapis.com/cmip6/pangeo-cmip6.json"
col = intake.open_esm_datastore(cat_url)
col
# Out:
# <p><strong>pangeo-cmip6 catalog with 7674 dataset(s) from 514818 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>activity_id</th>
#       <td>18</td>
#     </tr>
#     <tr>
#       <th>institution_id</th>
#       <td>36</td>
#     </tr>
#     <tr>
#       <th>source_id</th>
#       <td>88</td>
#     </tr>
#     <tr>
#       <th>experiment_id</th>
#       <td>170</td>
#     </tr>
#     <tr>
#       <th>member_id</th>
#       <td>657</td>
#     </tr>
#     <tr>
#       <th>table_id</th>
#       <td>37</td>
#     </tr>
#     <tr>
#       <th>variable_id</th>
#       <td>700</td>
#     </tr>
#     <tr>
#       <th>grid_label</th>
#       <td>10</td>
#     </tr>
#     <tr>
#       <th>zstore</th>
#       <td>514818</td>
#     </tr>
#     <tr>
#       <th>dcpp_init_year</th>
#       <td>60</td>
#     </tr>
#     <tr>
#       <th>version</th>
#       <td>736</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
cat = col.search( variable_id=['od550aer'], member_id=['r1i1p1f1'], experiment_id=['historical'])
cat.df
# Out:
#    activity_id     institution_id        source_id experiment_id member_id  \
# 0         CMIP          NOAA-GFDL         GFDL-CM4    historical  r1i1p1f1
# 1         CMIP               IPSL     IPSL-CM6A-LR    historical  r1i1p1f1
# 2         CMIP               NCAR      CESM2-WACCM    historical  r1i1p1f1
# 3         CMIP               NCAR            CESM2    historical  r1i1p1f1
# 4         CMIP              CCCma          CanESM5    historical  r1i1p1f1
# 5         CMIP                INM        INM-CM4-8    historical  r1i1p1f1
# 6         CMIP                INM        INM-CM5-0    historical  r1i1p1f1
# 7         CMIP  HAMMOZ-Consortium  MPI-ESM-1-2-HAM    historical  r1i1p1f1
# 8         CMIP              MPI-M    MPI-ESM1-2-LR    historical  r1i1p1f1
# 9         CMIP              MPI-M    MPI-ESM1-2-HR    historical  r1i1p1f1
# 10        CMIP          NOAA-GFDL        GFDL-ESM4    historical  r1i1p1f1
# 11        CMIP                NCC       NorESM2-LM    historical  r1i1p1f1
# 12        CMIP           NIMS-KMA       KACE-1-0-G    historical  r1i1p1f1
# 13        CMIP       E3SM-Project         E3SM-1-0    historical  r1i1p1f1
# 14        CMIP                BCC         BCC-ESM1    historical  r1i1p1f1
# 15        CMIP               NCAR  CESM2-WACCM-FV2    historical  r1i1p1f1
# 16        CMIP               NCAR        CESM2-FV2    historical  r1i1p1f1
# 17        CMIP       E3SM-Project         E3SM-1-1    historical  r1i1p1f1
# 18        CMIP       E3SM-Project     E3SM-1-1-ECA    historical  r1i1p1f1
# 19        CMIP                MRI       MRI-ESM2-0    historical  r1i1p1f1
#
#    table_id variable_id grid_label  \
# 0    AERmon    od550aer        gr1
# 1    AERmon    od550aer         gr
# 2    AERmon    od550aer         gn
# 3    AERmon    od550aer         gn
# 4    AERmon    od550aer         gn
# 5    AERmon    od550aer        gr1
# 6    AERmon    od550aer        gr1
# 7    AERmon    od550aer         gn
# 8    AERmon    od550aer         gn
# 9    AERmon    od550aer         gn
# 10   AERmon    od550aer        gr1
# 11   AERmon    od550aer         gn
# 12   AERmon    od550aer         gr
# 13   AERmon    od550aer         gr
# 14   AERmon    od550aer         gn
# 15   AERmon    od550aer         gn
# 16   AERmon    od550aer         gn
# 17   AERmon    od550aer         gr
# 18   AERmon    od550aer         gr
# 19   AERmon    od550aer         gn
#
#                                                zstore  dcpp_init_year  \
# 0   gs://cmip6/CMIP6/CMIP/NOAA-GFDL/GFDL-CM4/histo...             NaN
# 1   gs://cmip6/CMIP6/CMIP/IPSL/IPSL-CM6A-LR/histor...             NaN
# 2   gs://cmip6/CMIP6/CMIP/NCAR/CESM2-WACCM/histori...             NaN
# 3   gs://cmip6/CMIP6/CMIP/NCAR/CESM2/historical/r1...             NaN
# 4   gs://cmip6/CMIP6/CMIP/CCCma/CanESM5/historical...             NaN
# 5   gs://cmip6/CMIP6/CMIP/INM/INM-CM4-8/historical...             NaN
# 6   gs://cmip6/CMIP6/CMIP/INM/INM-CM5-0/historical...             NaN
# 7   gs://cmip6/CMIP6/CMIP/HAMMOZ-Consortium/MPI-ES...             NaN
# 8   gs://cmip6/CMIP6/CMIP/MPI-M/MPI-ESM1-2-LR/hist...             NaN
# 9   gs://cmip6/CMIP6/CMIP/MPI-M/MPI-ESM1-2-HR/hist...             NaN
# 10  gs://cmip6/CMIP6/CMIP/NOAA-GFDL/GFDL-ESM4/hist...             NaN
# 11  gs://cmip6/CMIP6/CMIP/NCC/NorESM2-LM/historica...             NaN
# 12  gs://cmip6/CMIP6/CMIP/NIMS-KMA/KACE-1-0-G/hist...             NaN
# 13  gs://cmip6/CMIP6/CMIP/E3SM-Project/E3SM-1-0/hi...             NaN
# 14  gs://cmip6/CMIP6/CMIP/BCC/BCC-ESM1/historical/...             NaN
# 15  gs://cmip6/CMIP6/CMIP/NCAR/CESM2-WACCM-FV2/his...             NaN
# 16  gs://cmip6/CMIP6/CMIP/NCAR/CESM2-FV2/historica...             NaN
# 17  gs://cmip6/CMIP6/CMIP/E3SM-Project/E3SM-1-1/hi...             NaN
# 18  gs://cmip6/CMIP6/CMIP/E3SM-Project/E3SM-1-1-EC...             NaN
# 19  gs://cmip6/CMIP6/CMIP/MRI/MRI-ESM2-0/historica...             NaN
#
#      version
# 0   20180301
# 1   20180803
# 2   20190227
# 3   20190308
# 4   20190429
# 5   20190530
# 6   20190610
# 7   20190627
# 8   20190710
# 9   20190710
# 10  20190726
# 11  20190815
# 12  20190911
# 13  20190916
# 14  20190918
# 15  20191120
# 16  20191120
# 17  20191211
# 18  20200127
# 19  20200207

# %%
dset_dict = cat.to_dataset_dict(zarr_kwargs={'use_cftime':True})
# Out:
# /srv/conda/envs/notebook/lib/python3.9/site-packages/intake_esm/core.py:882: UserWarning: There are no datasets to load! Returning an empty dictionary.
#   warn('There are no datasets to load! Returning an empty dictionary.')

# %% [markdown]
# `intake-esm` is build on top of [pandas](https://pandas.pydata.org/pandas-docs/stable). It is possible to view the `pandas.DataFrame` as follows.

# %%
dataset_list = list(dset_dict.keys())
dataset_list
# Out:
# []

# %%
dset = dset_dict[dataset_list[0]]
dset = dset.sel(member_id='r1i1p1f1',time=slice("2000-01-01", "2014-12-31"))
dset
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 dset = dset_dict[dataset_list[0]]
#       2 dset = dset.sel(member_id='r1i1p1f1',time=slice("2000-01-01", "2014-12-31"))
#       3 dset
#
# IndexError: list index out of range
